# %%
# Activity 1 

height = 165.0
weight = 59.0

_height = height / 100.0 \
        if height >= 2.2 \
        else height

bmi = weight / (_height ** 2)
bmi
# Out:
# 21.6712580348944

# %%
# Activity 2

list = [ 10000.0, 20000.0, 400000.0 ]
taxed = []

for number in list:
    result = number

    if (number > 150_000):
        result *= 0.05
    if (number > 300_000):
        result *= 0.10
    
    taxed.append(result)

taxed
# Out:
# [1000.0, 20000.0, 2000.0]
