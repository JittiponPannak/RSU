# %% [markdown]
# # Title
# ## Subtitle
# ### Topic 1
# #### Topic 2
# ##### Topic 3

# %% [markdown]
# ![Process](./process.jpg)

# %% [markdown]
# - **Data Acquisition**
# - *Data Cleansing*
# - Data Spilt
# - Model Training~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Mode Test
# - Model Deployment
