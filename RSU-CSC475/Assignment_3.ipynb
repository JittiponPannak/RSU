# %%
import pandas as pd
import pymysql

HOST = "localhost"
PORT = 3306
USER = "u6606405"
PASSWORD = "6606405"
DATABASE = "u6606405_mydb"

connection = pymysql.connect(
    host = HOST,
    port = PORT,
    user = USER,
    password = PASSWORD,
    database = DATABASE,
    )

cursor = connection.cursor()
cursor.execute(
    """
    CREATE TABLE IF NOT EXISTS pokemon (
        id INTEGER NOT NULL,
        name VARCHAR(255) NOT NULL,
        type_1 VARCHAR(255) NOT NULL,
        type_2 VARCHAR(255) NULL,
        total INTEGER NOT NULL,
        hp INTEGER NOT NULL,
        attack INTEGER NOT NULL,
        defense INTEGER NOT NULL,
        sp_attack INTEGER NOT NULL,
        sp_defense INTEGER NOT NULL,
        speed INTEGER NOT NULL,
        generation INTEGER NOT NULL,
        legendary BOOLEAN NOT NULL,
        PRIMARY KEY (id, name)
        );
    """
)
# Out:
# 0

# %%
cursor = connection.cursor()
cursor.execute("DROP TABLE pokemon;")
# Out:
# 0

# %%
import numpy as np

# https://www.kaggle.com/datasets/abcsds/pokemon
raw_data = pd.read_csv("./assets/Pokemon.csv")
raw_data = raw_data.head(100)
raw_data["Type 2"] = "" if not raw_data["Type 2"] is str else raw_data["Type 2"] 

data = [ tuple(row) for row in raw_data.itertuples(index=False) ]

cursor = connection.cursor()
cursor.executemany("INSERT INTO pokemon (id, name, type_1, type_2, total, hp, attack, defense, sp_attack, sp_defense, speed, generation, legendary) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", data)

connection.commit()
cursor.rowcount
# Out:
# 100

# %%
df_uri = "mysql+pymysql://u6606405:6606405@localhost/u6606405_mydb"
sql = "SELECT * FROM pokemon"

df = pd.read_sql(sql, df_uri)
df
# Out:
#     id                   name  type_1 type_2  total   hp  attack  defense  \
# 0    1              Bulbasaur   Grass           318   45      49       49
# 1    2                Ivysaur   Grass           405   60      62       63
# 2    3               Venusaur   Grass           525   80      82       83
# 3    3  VenusaurMega Venusaur   Grass           625   80     100      123
# 4    4             Charmander    Fire           309   39      52       43
# ..  ..                    ...     ...    ...    ...  ...     ...      ...
# 95  88                 Grimer  Poison           325   80      80       50
# 96  89                    Muk  Poison           500  105     105       75
# 97  90               Shellder   Water           305   30      65      100
# 98  91               Cloyster   Water           525   50      95      180
# 99  92                 Gastly   Ghost           310   30      35       30
#
#     sp_attack  sp_defense  speed  generation  legendary
# ...
