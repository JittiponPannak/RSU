# %% [markdown]
# ## Boxplot

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.rcParams['font.family'] = "tahoma"

# %%
e
df[['2559', '2560', '2561']].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ### Assignment

# %%
df = pd.read_csv("./assets/hypertension_all.csv")

df['2559_rate'] = df['2559'] * 100000 / df['ประชากรกลางปี']
df['2560_rate'] = df['2560'] * 100000 / df['ประชากรกลางปี']
df['2561_rate'] = df['2561'] * 100000 / df['ประชากรกลางปี']

df[['2559_rate', '2560_rate', '2561_rate']].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ## Groupby

# %%
 df = pd.read_csv("./assets/hypertension_all.csv")

df[['เขตบริการสุขภาพ', '2559', '2560', '2561', 'ประชากรกลางปี']]

by_zone = df.groupby('เขตบริการสุขภาพ')
by_zone.sum()
# Out:
#                                                            จังหวัด    2559  \
# เขตบริการสุขภาพ
# 0                                                    กรุงเทพมหานคร  133085
# 1                เชียงใหม่ลำพูนลำปางแพร่น่านพะเยาเชียงรายแม่ฮ่อ...  124236
# 2                             อุตรดิตถ์ตากสุโขทัยพิษณุโลกเพชรบูรณ์   75322
# 3                          ชัยนาทนครสวรรค์อุทัยธานีกำแพงเพชรพิจิตร   69792
# 4                นนทบุรีปทุมธานีพระนครศรีอยุธยาอ่างทองลพบุรีสิง...  110973
# 5                ราชบุรีกาญจนบุรีสุพรรณบุรีนครปฐมสมุทรสาครสมุทร...  121048
# 6                สมุทรปราการชลบุรีระยองจันทบุรีตราดฉะเชิงเทราปร...  106649
# 7                                ขอนแก่นมหาสารคามร้อยเอ็ดกาฬสินธุ์  104078
# 8                  บึงกาฬหนองบัวลำภูอุดรธานีเลยหนองคายสกลนครนครพนม   87749
# 9                               นครราชสีมาบุรีรัมย์สุรินทร์ชัยภูมิ  130148
# 10                      ศรีสะเกษอุบลราชธานียโสธรอำนาจเจริญมุกดาหาร   78061
# ...

# %%
 df = pd.read_csv("./assets/hypertension_all.csv")

df['2559_rate'] = df['2559'] * 100000 / df['ประชากรกลางปี']
df['2560_rate'] = df['2560'] * 100000 / df['ประชากรกลางปี']
df['2561_rate'] = df['2561'] * 100000 / df['ประชากรกลางปี']

df[['เขตบริการสุขภาพ', '2559_rate', '2560_rate', '2561_rate', 'ประชากรกลางปี']].mean().plot.bar()

plt.show()

# %%
df[df['จังหวัด'].str.contains("^ลำ.*")]
# Out:
#    เขตบริการสุขภาพ จังหวัด   2559   2560   2561  ประชากรกลางปี    2559_rate  \
# 2                1   ลำพูน   5616   5406   6992         403330  1392.408202
# 3                1   ลำปาง  19044  21150  22130         742078  2566.307046
#
#      2560_rate    2561_rate
# 2  1340.341656  1733.568046
# 3  2850.104706  2982.166295

# %% [markdown]
# ### Assignment 5

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.rcParams['font.family'] = "tahoma"

df = pd.read_csv("./assets/chronic_2016_90_all.csv", low_memory=False)
df['CHRONIC'].value_counts().head(10).plot.bar()
plt.show()
