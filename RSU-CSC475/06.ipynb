# %%
import pandas as pd

df1 = pd.read_csv("./assets/hypertension_60.csv")
df2 = pd.read_csv("./assets/hypertension_61.csv")

df_all = pd.merge(df1, df2)
df_all
# Out:
#     เขตบริการสุขภาพ        จังหวัด    2560    2561
# 0                 0  กรุงเทพมหานคร  128883  136418
# 1                 1      เชียงใหม่   33071   35546
# 2                 1          ลำพูน    5406    6992
# 3                 1          ลำปาง   21150   22130
# 4                 1           แพร่   15019   15262
# ..              ...            ...     ...     ...
# 72               12           ตรัง   16467   17421
# 73               12         พัทลุง   11398   12646
# 74               12        ปัตตานี    7513    7974
# 75               12           ยะลา    8652    8359
# 76               12       นราธิวาส   14736   17594
#
# [77 rows x 4 columns]

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = "tahoma"

df = pd.read_csv("./assets/hypertension_all.csv")
sns.histplot(df["2561"], color="skyblue", kde=True, bins=[ 0, 20000, 40000, 60000, 80000, 100000 ])
plt.title("จำนวนผู้ปว่วยความดันโลหิตสูง ปี 2561")
# Out:
# Text(0.5, 1.0, 'จำนวนผู้ปว่วยความดันโลหิตสูง ปี 2561')
