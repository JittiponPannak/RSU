# %%
h = 1.65 
w = 59.0
bmi = w / (h ** 2.0)

print("Height (m) : ", h)
print("Weight (kg) : ", w)
print("BMI : ", bmi)
# Out:
# Height (m) :  1.65
# Weight (kg) :  59.0
# BMI :  21.6712580348944

# %%
name = input("Enter your name : ")
weight = float(input("Enter your weight (kg) : "))
height = float(input("Enter your height (cm) : "))
age = int(input("Enter your age : "))
bmr = 88.362 + (13.397 * weight) + (4.799 * height) - (5.677 * age)

print(f"\nName : {name} | BMD : {bmr} kcal/day ")
# Out:
# Enter your name :  6606405 Jittipon Pannak
# Enter your weight (kg) :  65
# Enter your height (cm) :  170
# Enter your age :  30
# Name : 6606405 Jittipon Pannak | BMD : 1604.6870000000001 kcal/day

# %%
score = int(input("Input your score : "))
result = ""

if score >= 80:
    result = "A"
elif score >= 70:
    result = "B"
elif score >= 60:
    result = "C"
elif score >= 50:
    result = "D"
else:
    result = "F"

print("Your grade is : ", result)
# Out:
# Input your score :  79
# Your grade is :  B

# %%
principal = int(input("Enter principal amount : "))
interest = float(input("Enter interest rate : "))
years = int(input("Enter number of years : "))
result = principal

_interest = (interest / 100.0)

for i in range(years):
    result += result * _interest

print("Total amount after {} years : {}".format(years, result))
# Out:
# Enter principal amount :  100
# Enter interest rate :  3
# Enter number of years :  2
# Total amount after 2 years : 106.09
